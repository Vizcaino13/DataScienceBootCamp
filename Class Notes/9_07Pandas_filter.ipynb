# %%
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df_users.groupby("occupation").count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
df_users.groupby("occupation").gender.unique()

 #this is grouping the data by age and ocupation and counting the ages

# %%
df_doc = df_users[df_users['occupation'] == 'doctor'].groupby('gender').describe()

df_doc
# Out:
#        user_id                                                             \
#          count        mean         std    min    25%    50%    75%    max
# gender
# M          7.0  533.714286  330.491913  138.0  275.0  427.0  843.0  935.0
#
#          age
#        count       mean        std   min   25%   50%   75%   max
# gender
# M        7.0  43.571429  12.501428  28.0  35.5  45.0  48.5  64.0

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
raw_data
# Out:
# {'regiment': ['Nighthawks',
#   'Nighthawks',
#   'Nighthawks',
#   'Nighthawks',
#   'Dragoons',
#   'Dragoons',
#   'Dragoons',
#   'Dragoons',
#   'Scouts',
#   'Scouts',
#   'Scouts',
#   'Scouts'],
#  'company': ['1st',
#   '1st',
#   '2nd',
#   '2nd',
#   '1st',
#   '1st',
#   '2nd',
#   '2nd',
#   '1st',
#   '1st',
#   '2nd',
#   '2nd'],
#  'name': ['Miller',
#   'Jacobson',
#   'Ali',
#   'Milner',
#   'Cooze',
#   'Jacon',
#   'Ryaner',
#   'Sone',
#   'Sloan',
#   'Piger',
#   'Riani',
#   'Ali'],
#  'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
#  'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
regiment = pd.DataFrame(raw_data, columns = raw_data.keys())

# %%
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
regiment.groupby("regiment").company.count() # This code groups the dataset by the "regiment" column and counts the number of unique companies within each regiment.
# Out:
# regiment
# Dragoons      4
# Nighthawks    4
# Scouts        4
# Name: company, dtype: int64

# %%
regiment[regiment['regiment']=='Scouts'].groupby('regiment').count() #only on the basis of scout
# Out:
#           company  name  preTestScore  postTestScore
# regiment
# Scouts          4     4             4              4

# %%
regiment[["regiment", "company"]]
# Out:
#       regiment company
# 0   Nighthawks     1st
# 1   Nighthawks     1st
# 2   Nighthawks     2nd
# 3   Nighthawks     2nd
# 4     Dragoons     1st
# 5     Dragoons     1st
# 6     Dragoons     2nd
# 7     Dragoons     2nd
# 8       Scouts     1st
# 9       Scouts     1st
# 10      Scouts     2nd
# 11      Scouts     2nd

# %%
regiment[["regiment", "company"]].count() #counting all the regiments and companies
# Out:
# regiment    12
# company     12
# dtype: int64

# %%
regiment[regiment['name']=='Miller'].groupby(['regiment',"company"]).describe()
# Out:
#                    preTestScore                                    \
#                           count mean std  min  25%  50%  75%  max
# regiment   company
# Nighthawks 1st              1.0  4.0 NaN  4.0  4.0  4.0  4.0  4.0
#
#                    postTestScore
#                            count  mean std   min   25%   50%   75%   max
# regiment   company
# Nighthawks 1st               1.0  25.0 NaN  25.0  25.0  25.0  25.0  25.0

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
df_uscrime=pd.read_csv(url)
df_uscrime

# %%
df_uscrime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df_uscrime.shape
# Out:
# (55, 12)

# %%
df_uscrime.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
df_uscrime.index
# Out:
# RangeIndex(start=0, stop=55, step=1)

# %%
df_uscrime["Violent"].sum() #total of all violent crimes
# Out:
# 65384309

# %%
df_uscrime.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
df_uscrime.loc[0:2,"Violent":].max() #max amount of crimes for Violent through theft for the year of 1961
# Out:
# Violent                301510
# Property              3450700
# Murder                   9110
# Forcible_Rape           17550
# Robbery                110860
# Aggravated_assault     164570
# Burglary               994300
# Larceny_Theft         2089600
# Vehicle_Theft          366800
# dtype: int64

# %%
df_uscrime.shape
# Out:
# (55, 12)

# %%
df_uscrime["Property"].min()
# Out:
# 3095700

# %%
df_uscrime.loc[:"1961","Population":].max()
# Out:
# Population            220099000
# Total                  12249500
# Violent                 1208030
# Property               11041500
# Murder                    21460
# Forcible_Rape             76390
# Robbery                  480700
# Aggravated_assault       629480
# Burglary                3327700
# Larceny_Theft           6601000
# Vehicle_Theft           1112800
# dtype: int64

# %%
#syntax .iloc

#df.iloc[index row start :index row end ,index column start:index column end]

# %%
x = [1, 2, 3, 4, 5]

y = x[1:4]

print(y)
# Out:
# [2, 3, 4]

# %%
x = [10, 20, 30, 40, 50]

y = x[-3:]
print(y)
# Out:
# [30, 40, 50]

# %%
#merging data , when merging there shoukd be common columns inbetween or it should have the same structure

raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

# %%
data_new = pd.concat([data1, data2])
data_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_row = pd.concat([data1, data2], axis=0)
data_new_row
#whatever data from data 1 and data2 is there, this is based on row
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
#concatinate on column
# this is based on column
data_new_col=pd.concat([data1,data2],  axis=1)
data_new_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
pd.merge(data_new, data3, on="subject_id") #this is the common value inbetween
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15
