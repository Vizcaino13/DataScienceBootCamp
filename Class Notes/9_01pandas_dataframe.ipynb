# %%
import numpy as np
import pandas as pd

# %%
#creating a data frame

#python pandas data frame

lst1=[12,23,34,45,56,67,78,89,90,110]

df1=pd.DataFrame(lst1)
print(df1)
type(df1)
# Out:
#      0
# 0   12
# 1   23
# 2   34
# 3   45
# 4   56
# 5   67
# 6   78
# 7   89
# 8   90
# 9  110
# pandas.core.frame.DataFrame

# %%
lang=["c","c++","java","python"]
df2=pd.DataFrame(lang)
df2
# Out:
#         0
# 0       c
# 1     c++
# 2    java
# 3  python

# %%
rating=[4,3,2,1]
df2[1]=rating
df2
# Out:
#         0  1
# 0       c  4
# 1     c++  3
# 2    java  2
# 3  python  1

# %%
df2.columns=["language", "rating"]
df2
# Out:
#   language  rating
# 0        c       4
# 1      c++       3
# 2     java       2
# 3   python       1

# %%
foods=("plantano","eggs","potato","milk")

df3=pd.DataFrame(foods)
df3
# Out:
#           0
# 0  plantano
# 1      eggs
# 2    potato
# 3      milk

# %%
rank=["great", "good", "okay","bad"]
df3[1]=rank
df3
# Out:
#           0      1
# 0  plantano  great
# 1      eggs   good
# 2    potato   okay
# 3      milk    bad

# %%
df3.columns=["food", "taste"]
df3
# Out:
#        food  taste
# 0  plantano  great
# 1      eggs   good
# 2    potato   okay
# 3      milk    bad

# %%
#create a data frame dictionary

data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df2 = pd.DataFrame(data)
df3 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b'])
df4 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c'])
df5 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c' , 'd'])

# %%
df2
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
df3
# Out:
#       a   b
# row1  1   2
# row2  5  10

# %%
df4
# Out:
#       a   b     c
# row1  1   2   NaN
# row2  5  10  20.0

# %%
df5
# Out:
#       a   b     c   d
# row1  1   2   NaN NaN
# row2  5  10  20.0 NaN

# %%
df6 = pd.DataFrame({'ID':[1,2,3,4], 'Name':['Ramesh','Suresh','Naresh','Sukesh']})
df6
# Out:
#    ID    Name
# 0   1  Ramesh
# 1   2  Suresh
# 2   3  Naresh
# 3   4  Sukesh

# %%
df6["ID"], df6["Name"]
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  Name: ID, dtype: int64,
#  0    Ramesh
#  1    Suresh
#  2    Naresh
#  3    Sukesh
#  Name: Name, dtype: object)

# %%
dict1={"A":pd.Series([1,2,3,4], index=["a","b","c","d"]),
       "B":pd.Series([1,2,3,4,5], index=["a","b","c","d","e"])
       }

df1=pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
#Data frame of random numbers with date indices

dates=pd.date_range(start="01-Aug-2023", end="31-Aug-2023")

# %%
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates= pd.date_range("today", periods=7)

# %%
dates
# Out:
# DatetimeIndex(['2023-09-02 00:37:45.304796', '2023-09-03 00:37:45.304796',
#                '2023-09-04 00:37:45.304796', '2023-09-05 00:37:45.304796',
#                '2023-09-06 00:37:45.304796', '2023-09-07 00:37:45.304796',
#                '2023-09-08 00:37:45.304796'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates= pd.date_range("2023-08-24", periods=7)
dates
# Out:
# DatetimeIndex(['2023-08-24', '2023-08-25', '2023-08-26', '2023-08-27',
#                '2023-08-28', '2023-08-29', '2023-08-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
M = np.random.random((7,7))
M
# Out:
# array([[0.10369672, 0.0157748 , 0.83511135, 0.67134933, 0.20170663,
#         0.64308506, 0.54085342],
#        [0.25748582, 0.15770353, 0.54549817, 0.99145097, 0.17350735,
#         0.81300085, 0.04160784],
#        [0.40661893, 0.03287604, 0.76226334, 0.88050563, 0.79539216,
#         0.52507405, 0.95001062],
#        [0.76149038, 0.95170208, 0.21650637, 0.07320458, 0.58378609,
#         0.0546559 , 0.55855562],
#        [0.05682543, 0.46597253, 0.93578753, 0.73925615, 0.37735799,
#         0.67348249, 0.74626553],
#        [0.53274425, 0.41301218, 0.85107332, 0.22805599, 0.40328551,
#         0.55484637, 0.34933271],
#        [0.9354059 , 0.34984987, 0.25448485, 0.28488378, 0.1189228 ,
#         0.08209697, 0.29457135]])

# %%
df= pd.DataFrame(M, index=dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  4.0
# e  NaN

# %%
dict = {'A' : pd.Series([1, 2, 3,11], index=['a', 'b', 'c','d']),
'B' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df12 = pd.DataFrame(dict)
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1, inplace=True) #this is to delete stuff,  axis=0 is the  rows,  axis=1  is columns, you must use inplace to delete it permentaly
df12
# Out:
#    B
# a  1
# b  2
# c  3
# d  4

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10,100,30) #values are between 10 and 100
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10
# Out:
#             C1  C2
# 0    10.000000  91
# 1    13.103448  45
# 2    16.206897  38
# 3    19.310345  73
# 4    22.413793  86
# 5    25.517241  51
# 6    28.620690  52
# 7    31.724138  22
# 8    34.827586  85
# 9    37.931034  46
# 10   41.034483  23
# 11   44.137931  41
# 12   47.241379  95
# 13   50.344828  87
# 14   53.448276  22
# 15   56.551724  94
# 16   59.655172  87
# 17   62.758621  61
# 18   65.862069  18
# 19   68.965517  29
# 20   72.068966  74
# 21   75.172414  70
# 22   78.275862  52
# 23   81.379310  76
# 24   84.482759  57
# 25   87.586207  63
# 26   90.689655  99
# 27   93.793103  34
# 28   96.896552  33
# 29  100.000000  82

# %%
df10= df10.drop([17,18,19], axis= 0) #this is to delete the rows of 17,18,19
df10
# Out:
#             C1  C2
# 0    10.000000  93
# 1    13.103448  14
# 2    16.206897  20
# 3    19.310345  45
# 4    22.413793  88
# 5    25.517241  12
# 6    28.620690  35
# 7    31.724138  45
# 8    34.827586  84
# 9    37.931034  16
# 10   41.034483  78
# 11   44.137931  93
# 12   47.241379  82
# 13   50.344828  30
# 14   53.448276  76
# 15   56.551724  20
# 16   59.655172  99
# 20   72.068966  59
# 21   75.172414  58
# 22   78.275862  41
# 23   81.379310  12
# 24   84.482759  31
# 25   87.586207  81
# 26   90.689655  92
# 27   93.793103  88
# 28   96.896552  67
# 29  100.000000  14

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  93
# 1    13.103448  14
# 2    16.206897  20
# 3    19.310345  45
# 4    22.413793  88
# 5    25.517241  12
# 6    28.620690  35
# 7    31.724138  45
# 8    34.827586  84
# 9    37.931034  16
# 10   41.034483  78
# 11   44.137931  93
# 12   47.241379  82
# 13   50.344828  30
# 14   53.448276  76
# 15   56.551724  20
# 16   59.655172  99
# 20   72.068966  59
# 21   75.172414  58
# 22   78.275862  41
# 23   81.379310  12
# 24   84.482759  31
# 25   87.586207  81
# 26   90.689655  92
# 27   93.793103  88
# 28   96.896552  67
# 29  100.000000  14

# %%
df10= df10.drop([16], axis= 0, inplace=True) #this is to delete the rows of 17,18,19
df10

# %%
df10

# %%
df10.drop(df10.index[5], inplace= True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-4fe37b089429> in <cell line: 1>()
# ----> 1 df10.drop(df10.index[5], inplace= True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df10

# %%
df10.iloc[10:15] #this only prints out rows 10-15
# Out:
#            C1  C2
# 10  41.034483  23
# 11  44.137931  41
# 12  47.241379  95
# 13  50.344828  87
# 14  53.448276  22

# %%
df10.iloc[10:, 0:]
# Out:
#             C1  C2
# 10   41.034483  23
# 11   44.137931  41
# 12   47.241379  95
# 13   50.344828  87
# 14   53.448276  22
# 15   56.551724  94
# 16   59.655172  87
# 17   62.758621  61
# 18   65.862069  18
# 19   68.965517  29
# 20   72.068966  74
# 21   75.172414  70
# 22   78.275862  52
# 23   81.379310  76
# 24   84.482759  57
# 25   87.586207  63
# 26   90.689655  99
# 27   93.793103  34
# 28   96.896552  33
# 29  100.000000  82

# %%
df10.loc[10:15] #see what is the difference between ilock and loc
# Out:
#            C1  C2
# 10  41.034483  23
# 11  44.137931  41
# 12  47.241379  95
# 13  50.344828  87
# 14  53.448276  22
# 15  56.551724  94
