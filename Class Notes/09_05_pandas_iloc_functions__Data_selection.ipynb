# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
M = np.random.random((7,7))
M
# Out:
# array([[0.11019676, 0.12497543, 0.92598099, 0.25419852, 0.37743371,
#         0.35973651, 0.07335944],
#        [0.30339775, 0.51806361, 0.04419226, 0.52779251, 0.47636661,
#         0.57656604, 0.62312002],
#        [0.9210975 , 0.20487399, 0.61709422, 0.80783456, 0.69811215,
#         0.17284065, 0.60704165],
#        [0.81610677, 0.91754883, 0.76433628, 0.23506555, 0.64453244,
#         0.48953758, 0.86260408],
#        [0.72626457, 0.88495418, 0.20060698, 0.80836771, 0.46488447,
#         0.49190967, 0.07282158],
#        [0.91609805, 0.42174821, 0.16973111, 0.52260343, 0.69134975,
#         0.4054443 , 0.64000318],
#        [0.1304001 , 0.78928597, 0.70834718, 0.28050404, 0.05817626,
#         0.49898607, 0.25833185]])

# %%
dates= pd.date_range("2023-08-24", periods=7)
dates
# Out:
# DatetimeIndex(['2023-08-24', '2023-08-25', '2023-08-26', '2023-08-27',
#                '2023-08-28', '2023-08-29', '2023-08-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
df= pd.DataFrame(M, index=dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                    6
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.columns=["C1","C2","C3","C4","C5","C6","C7"]
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.sort_values(by ="C1", ascending=True)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-30  0.258332
# 2023-08-25  0.623120
# 2023-08-28  0.072822
# 2023-08-27  0.862604
# 2023-08-29  0.640003
# 2023-08-26  0.607042

# %%
df.loc[:,:] #this is patching all rows and all columns, 1st one is row, second colmn
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.loc["2023-08-28"	:,:]  #this is this row, and ahead 2023-08-28
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.loc[:"2023-08-28"	,:] #this is before 2023-08-28
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822

# %%
df.loc[:,"C4":]
# Out:
#                   C4        C5        C6        C7
# 2023-08-24  0.254199  0.377434  0.359737  0.073359
# 2023-08-25  0.527793  0.476367  0.576566  0.623120
# 2023-08-26  0.807835  0.698112  0.172841  0.607042
# 2023-08-27  0.235066  0.644532  0.489538  0.862604
# 2023-08-28  0.808368  0.464884  0.491910  0.072822
# 2023-08-29  0.522603  0.691350  0.405444  0.640003
# 2023-08-30  0.280504  0.058176  0.498986  0.258332

# %%
df.loc[:,:"C4"]#all columns before c4
# Out:
#                   C1        C2        C3        C4
# 2023-08-24  0.110197  0.124975  0.925981  0.254199
# 2023-08-25  0.303398  0.518064  0.044192  0.527793
# 2023-08-26  0.921098  0.204874  0.617094  0.807835
# 2023-08-27  0.816107  0.917549  0.764336  0.235066
# 2023-08-28  0.726265  0.884954  0.200607  0.808368
# 2023-08-29  0.916098  0.421748  0.169731  0.522603
# 2023-08-30  0.130400  0.789286  0.708347  0.280504

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.loc["2023-08-24":"2023-08-24", "C1":"C1"]
# Out:
#                   C1
# 2023-08-24  0.110197

# %%
df.loc["2023-08-25":"2023-08-25	", "C2":"C2"]
# Out:
#                   C2
# 2023-08-25  0.518064

# %%
df.loc["2023-08-26":"2023-08-26	", "C3":"C3"]
# Out:
#                   C3
# 2023-08-26  0.617094

# %%
df.loc["2023-08-27":"2023-08-27	", "C4":"C4"]
# Out:
#                   C4
# 2023-08-27  0.235066

# %%
df.loc["2023-08-28":"2023-08-28	", "C5":"C5"]
# Out:
#                   C5
# 2023-08-28  0.464884

# %%
df.loc["2023-08-29":"2023-08-29	", "C6":"C6"]
# Out:
#                   C6
# 2023-08-29  0.405444

# %%
df.loc["2023-08-30":"2023-08-30	", "C7":"C7"]
# Out:
#                   C7
# 2023-08-30  0.258332

# %%
df.loc["2023-08-30":"2023-08-30	", "C1":"C1"]
# Out:
#                 C1
# 2023-08-30  0.1304

# %%
df.loc["2023-08-29":"2023-08-29	", "C2":"C2"]
# Out:
#                   C2
# 2023-08-29  0.421748

# %%
df.loc["2023-08-28":"2023-08-28	", "C3":"C3"]
# Out:
#                   C3
# 2023-08-28  0.200607

# %%
df.loc["2023-08-27":"2023-08-27	", "C4":"C4"]
# Out:
#                   C4
# 2023-08-27  0.235066

# %%
df.loc["2023-08-26":"2023-08-26	", "C5":"C5"]
# Out:
#                   C5
# 2023-08-26  0.698112

# %%
df.loc["2023-08-25":"2023-08-25	", "C6":"C6"]
# Out:
#                   C6
# 2023-08-25  0.576566

# %%
df.loc["2023-08-24":"2023-08-24	", "C7":"C7"]
# Out:
#                   C7
# 2023-08-24  0.073359

# %%
# snytax of .loc

# df.loc[start row: end row, start column: end column]

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.iloc[:,:] #this gives all values by default, iloc is for the index
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.iloc[3:,:] #27th of august is index 3
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.iloc[:3,:]  #you want it to end on the 3rd index which is aug 27th
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042

# %%
df.iloc[:4,:] #if i want to print up to the august 27th then its 4th index
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604

# %%
df.iloc[:,3:] #starts from c4 is at index (3)and goes to c7
# Out:
#                   C4        C5        C6        C7
# 2023-08-24  0.254199  0.377434  0.359737  0.073359
# 2023-08-25  0.527793  0.476367  0.576566  0.623120
# 2023-08-26  0.807835  0.698112  0.172841  0.607042
# 2023-08-27  0.235066  0.644532  0.489538  0.862604
# 2023-08-28  0.808368  0.464884  0.491910  0.072822
# 2023-08-29  0.522603  0.691350  0.405444  0.640003
# 2023-08-30  0.280504  0.058176  0.498986  0.258332

# %%
df.iloc[:,:4]
# Out:
#                   C1        C2        C3        C4
# 2023-08-24  0.110197  0.124975  0.925981  0.254199
# 2023-08-25  0.303398  0.518064  0.044192  0.527793
# 2023-08-26  0.921098  0.204874  0.617094  0.807835
# 2023-08-27  0.816107  0.917549  0.764336  0.235066
# 2023-08-28  0.726265  0.884954  0.200607  0.808368
# 2023-08-29  0.916098  0.421748  0.169731  0.522603
# 2023-08-30  0.130400  0.789286  0.708347  0.280504

# %%
df.iloc[:,:2] #lets say you need c1, c2, c5,c6,c7
# Out:
#                   C1        C2
# 2023-08-24  0.110197  0.124975
# 2023-08-25  0.303398  0.518064
# 2023-08-26  0.921098  0.204874
# 2023-08-27  0.816107  0.917549
# 2023-08-28  0.726265  0.884954
# 2023-08-29  0.916098  0.421748
# 2023-08-30  0.130400  0.789286

# %%
df.iloc[:,4:] #this is the c5,c6,c7
# Out:
#                   C5        C6        C7
# 2023-08-24  0.377434  0.359737  0.073359
# 2023-08-25  0.476367  0.576566  0.623120
# 2023-08-26  0.698112  0.172841  0.607042
# 2023-08-27  0.644532  0.489538  0.862604
# 2023-08-28  0.464884  0.491910  0.072822
# 2023-08-29  0.691350  0.405444  0.640003
# 2023-08-30  0.058176  0.498986  0.258332

# %%
#syntax .iloc

#df.iloc[index row start :index row end ,index column start:index column end]

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-24  0.110197  0.124975  0.925981  0.254199  0.377434  0.359737
# 2023-08-25  0.303398  0.518064  0.044192  0.527793  0.476367  0.576566
# 2023-08-26  0.921098  0.204874  0.617094  0.807835  0.698112  0.172841
# 2023-08-27  0.816107  0.917549  0.764336  0.235066  0.644532  0.489538
# 2023-08-28  0.726265  0.884954  0.200607  0.808368  0.464884  0.491910
# 2023-08-29  0.916098  0.421748  0.169731  0.522603  0.691350  0.405444
# 2023-08-30  0.130400  0.789286  0.708347  0.280504  0.058176  0.498986
#
#                   C7
# 2023-08-24  0.073359
# 2023-08-25  0.623120
# 2023-08-26  0.607042
# 2023-08-27  0.862604
# 2023-08-28  0.072822
# 2023-08-29  0.640003
# 2023-08-30  0.258332

# %%
df.iloc[6:,6:]
# Out:
#                   C7
# 2023-08-30  0.258332

# %%
df.iloc[5:6,5:6] #start at the 5 index and ends at the 6 index, start at 5th column end at 7th because it wont print out the next index
# Out:
#                   C6
# 2023-08-29  0.405444

# %%
df.iloc[4:5,4:5]
# Out:
#                   C5
# 2023-08-28  0.464884

# %%
df.iloc[3,3]
# Out:
# 0.23506554894177079

# %%
df.iloc[2,2]
# Out:
# 0.6170942150494098

# %%
df.iloc[1,1]
# Out:
# 0.5180636116424995

# %%
path="/content/Churn_Modelling (1).csv"

df_churn_mod=pd.read_csv(path)

df_churn_mod
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod.loc[:,"Geography":"Age"]
# Out:
#      Geography  Gender  Age
# 0       France  Female   42
# 1        Spain  Female   41
# 2       France  Female   42
# 3       France  Female   39
# 4        Spain  Female   43
# ...        ...     ...  ...
# 9995    France    Male   39
# 9996    France    Male   35
# 9997    France  Female   36
# 9998   Germany    Male   42
# 9999    France  Female   28
#
# [10000 rows x 3 columns]

# %%
#oldest age is
print("youngest age", df_churn_mod.Age.max())


print("youngest age ",df_churn_mod.Age.min() )

df_churn_mod.Gender.describe()
# Out:
# youngest age 92
# youngest age  18
# count     10000
# unique        2
# top        Male
# freq       5457
# Name: Gender, dtype: object

# %%
df_churn_mod.iloc[4:,3:]
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 4             850     Spain  Female   43       2  125510.82              1
# 5             645     Spain    Male   44       8  113755.78              2
# 6             822    France    Male   50       7       0.00              2
# 7             376   Germany  Female   29       4  115046.74              4
# 8             501    France    Male   44       4  142051.07              2
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df_churn_mod.iloc[2:3,2:6]
# Out:
#   Surname  CreditScore Geography  Gender
# 2    Onio          502    France  Female

# %%
df_churn_mod
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod.info() #this gives all the info of the columns, object means string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df_churn_mod.describe() #gives all the stats
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df_churn_mod.describe
# Out:
# <bound method NDFrame.describe of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
df_churn_mod.describe(include="all")
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
df_churn_mod.dtypes #this just gives the data types
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df_churn_mod.size  #there are 140,000 values
# Out:
# 140000

# %%
df_churn_mod.ndim #gives dimesion of data, it is 2 dimesional
# Out:
# 2

# %%
df_churn_mod.columns #gives all the columns in the data set
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churn_mod.count
# Out:
# <bound method DataFrame.count of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
df_churn_mod.shape #this gives the shape data 10,000 rows and 14 columns
# Out:
# (10000, 14)

# %%
df_churn_mod.isnull() #this gives you stats on how many values are null
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
df_churn_mod.isnull().sum(axis=None) #this gives the total of all null columns, there are no nulls in this data
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
print(df_churn_mod.info())

print("================================================================================describe()")
print(df_churn_mod.describe())
print("================================================================================ describe all")
print("describeincludefunction ", df_churn_mod.describe(include="all") )
print("================================================================================dtypes")
print(df_churn_mod.dtypes)
print("================================================================================size")
print(df_churn_mod.size  )
print("================================================================================ndim")
print(df_churn_mod.ndim)
print("================================================================================columns")
print(df_churn_mod.columns)
print("================================================================================count")
print(df_churn_mod.count)
print("================================================================================shape")
print(df_churn_mod.shape)
print("================================================================================isnull")
print(df_churn_mod.isnull())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# None
# ...

# %%
df_churn_mod.min() #minimum valuie of each colulmn
# Out:
# RowNumber                 1
# CustomerId         15565701
# Surname               Abazu
# CreditScore             350
# Geography            France
# Gender               Female
# Age                      18
# Tenure                    0
# Balance                 0.0
# NumOfProducts             1
# HasCrCard                 0
# IsActiveMember            0
# EstimatedSalary       11.58
# Exited                    0
# dtype: object

# %%
df_churn_mod.max()#max valuie of each colulmn
# Out:
# RowNumber              10000
# CustomerId          15815690
# Surname               Zuyeva
# CreditScore              850
# Geography              Spain
# Gender                  Male
# Age                       92
# Tenure                    10
# Balance            250898.09
# NumOfProducts              4
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    199992.48
# Exited                     1
# dtype: object

# %%
df_churn_mod.std() #standard deviation
# Out:
# <ipython-input-68-5bdd361cd0c9>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_churn_mod.std() #standard deviation
# RowNumber           2886.895680
# CustomerId         71936.186123
# CreditScore           96.653299
# Age                   10.487806
# Tenure                 2.892174
# Balance            62397.405202
# NumOfProducts          0.581654
# HasCrCard              0.455840
# IsActiveMember         0.499797
# EstimatedSalary    57510.492818
# Exited                 0.402769
# dtype: float64

# %%
df_churn_mod.sum() #sum pf thingsa
# Out:
# RowNumber                                                   50005000
# CustomerId                                              156909405694
# Surname            HargraveHillOnioBoniMitchellChuBartlettObinnaH...
# CreditScore                                                  6505288
# Geography          FranceSpainFranceFranceSpainSpainFranceGermany...
# Gender             FemaleFemaleFemaleFemaleFemaleMaleMaleFemaleMa...
# Age                                                           389218
# Tenure                                                         50128
# Balance                                                 764858892.88
# NumOfProducts                                                  15302
# HasCrCard                                                       7055
# IsActiveMember                                                  5151
# EstimatedSalary                                        1000902398.81
# Exited                                                          2037
# ...

# %%
df_churn_mod.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churn_mod.CreditScore
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
df_churn_mod["CreditScore"]
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
#this is how to print the columns of both but two different values

df_churn_mod.CreditScore, df_churn_mod.Geography
# Out:
# (0       619
#  1       608
#  2       502
#  3       699
#  4       850
#         ...
#  9995    771
#  9996    516
#  9997    709
#  9998    772
#  9999    792
#  Name: CreditScore, Length: 10000, dtype: int64,
#  0        France
#  1         Spain
#  2        France
#  3        France
#  4         Spain
#           ...
#  9995     France
#  9996     France
#  9997     France
#  9998    Germany
#  9999     France
#  Name: Geography, Length: 10000, dtype: object)

# %%
df_churn_mod[["CreditScore", "Geography"]] #this will give both values together and it it uses t2 brackets since its 2v dimesional data
# Out:
#       CreditScore Geography
# 0             619    France
# 1             608     Spain
# 2             502    France
# 3             699    France
# 4             850     Spain
# ...           ...       ...
# 9995          771    France
# 9996          516    France
# 9997          709    France
# 9998          772   Germany
# 9999          792    France
#
# [10000 rows x 2 columns]

# %%
df_churn_mod[['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography']]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography
# 0             1    15634602   Hargrave          619    France
# 1             2    15647311       Hill          608     Spain
# 2             3    15619304       Onio          502    France
# 3             4    15701354       Boni          699    France
# 4             5    15737888   Mitchell          850     Spain
# ...         ...         ...        ...          ...       ...
# 9995       9996    15606229   Obijiaku          771    France
# 9996       9997    15569892  Johnstone          516    France
# 9997       9998    15584532        Liu          709    France
# 9998       9999    15682355  Sabbatini          772   Germany
# 9999      10000    15628319     Walker          792    France
#
# [10000 rows x 5 columns]

# %%
df_churn_mod.RowNumber, df_churn_mod.CustomerId,df_churn_mod.Surname, df_churn_mod.CreditScore
# Out:
# (0           1
#  1           2
#  2           3
#  3           4
#  4           5
#          ...
#  9995     9996
#  9996     9997
#  9997     9998
#  9998     9999
#  9999    10000
#  Name: RowNumber, Length: 10000, dtype: int64,
#  0       15634602
#  1       15647311
#  2       15619304
#  3       15701354
#  4       15737888
#            ...
#  9995    15606229
#  9996    15569892
#  9997    15584532
#  9998    15682355
#  9999    15628319
#  Name: CustomerId, Length: 10000, dtype: int64,
#  0        Hargrave
#  1            Hill
#  2            Onio
#  3            Boni
#  4        Mitchell
#            ...
#  9995     Obijiaku
#  9996    Johnstone
#  9997          Liu
#  9998    Sabbatini
#  9999       Walker
#  Name: Surname, Length: 10000, dtype: object,
#  0       619
#  1       608
#  2       502
#  3       699
#  4       850
#         ...
#  9995    771
#  9996    516
#  9997    709
#  9998    772
#  9999    792
#  Name: CreditScore, Length: 10000, dtype: int64)

# %%
# Data selection based on conditions

df_churn_mod[df_churn_mod.Gender=="Male"] #comparsion operations used here  #this is data based on conditions you put in
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %%
df_churn_mod[(df_churn_mod.Gender == 'Male') & (df_churn_mod.Age >= 45)] #this is data based on conditions you put in
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  \
# 6             7    15592531  Bartlett          822    France   Male   50
# 15           16    15643966   Goforth          616   Germany   Male   45
# 16           17    15737452     Romeo          653   Germany   Male   58
# 18           19    15661507   Muldrow          587     Spain   Male   45
# 23           24    15725737    Mosman          669    France   Male   46
# ...         ...         ...       ...          ...       ...    ...  ...
# 9953       9954    15655952     Burke          550    France   Male   47
# 9954       9955    15739850  Trentino          645    France   Male   45
# 9967       9968    15603794  Pugliesi          623    France   Male   48
# 9975       9976    15666295     Smith          610   Germany   Male   50
# 9986       9987    15581736  Bartlett          673   Germany   Male   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod[(df_churn_mod.Gender == 'Male') & (df_churn_mod.Age >= 45) & (df_churn_mod.Balance >100000)]

#this is looking for males who are older than or is 45 and who have a balance greater than 100,000
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography Gender  Age  \
# 15           16    15643966     Goforth          616   Germany   Male   45
# 16           17    15737452       Romeo          653   Germany   Male   58
# 56           57    15630053        Tsao          656    France   Male   45
# 70           71    15703793  Konovalova          738   Germany   Male   58
# 91           92    15731511     Ritchie          808    France   Male   45
# ...         ...         ...         ...          ...       ...    ...  ...
# 9917       9918    15755731       Davis          635   Germany   Male   53
# 9954       9955    15739850    Trentino          645    France   Male   45
# 9967       9968    15603794    Pugliesi          623    France   Male   48
# 9975       9976    15666295       Smith          610   Germany   Male   50
# 9986       9987    15581736    Bartlett          673   Germany   Male   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod[(df_churn_mod.Gender == 'Male') & (df_churn_mod.Age == df_churn_mod.Age.max()) ]
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender  Age  \
# 6443       6444    15764927  Rogova          753    France   Male   92
# 6759       6760    15660878   T'ien          705    France   Male   92
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6443       3  121513.31              1          0               1
# 6759       1  126076.24              2          1               1
#
#       EstimatedSalary  Exited
# 6443        195563.99       0
# 6759         34436.83       0

# %%
df_churn_mod[(df_churn_mod.Gender == 'Female') & (df_churn_mod.Age == df_churn_mod.Age.min()) ]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# 4556       4557    15796231      Nwankwo          681    France  Female   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1678       4   82767.42              1          1               0
# 2021       3  128743.80              1          0               0
# 4556       1   98894.39              1          1               1
# 9520       2   93816.70              2          1               0
#
#       EstimatedSalary  Exited
# 1678         71811.90       0
# 2021        197322.13       0
# 4556          9596.40       0
# 9520        126172.11       0

# %%
df_churn_mod[(df_churn_mod.CreditScore == 420) & (df_churn_mod.EstimatedSalary <= 50000)]
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  \
# 4933       4934    15787597     Hsu          420   Germany  Female   31
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4933       1  108377.75              2          1               1
#
#       EstimatedSalary  Exited
# 4933          9904.63       0

# %%
df_churn_mod[(df_churn_mod.CreditScore == 420) & ((df_churn_mod.EstimatedSalary >= 50000)| (df_churn_mod.EstimatedSalary <= 60000)) ]

#| is used as an or and you have to double parathesis this
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 1107       1108    15660316  Stephenson          420   Germany  Female   34
# 3389       3390    15724863    Sheppard          420     Spain  Female   55
# 4933       4934    15787597         Hsu          420   Germany  Female   31
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1107       1  135549.90              1          0               0
# 3389       4   91893.32              1          1               0
# 4933       1  108377.75              2          1               1
#
#       EstimatedSalary  Exited
# 1107        149471.13       1
# 3389        144870.28       1
# 4933          9904.63       0

# %%
df_churn_mod.Geography.unique() #this gives all the unique values in that column
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df_churn_mod[(df_churn_mod.Gender == 'Female') & (df_churn_mod.Geography.isin(['France', 'Germany']))]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602     Hargrave          619    France  Female   42
# 2             3    15619304         Onio          502    France  Female   42
# 3             4    15701354         Boni          699    France  Female   39
# 7             8    15656148       Obinna          376   Germany  Female   29
# 12           13    15632264          Kay          476    France  Female   34
# ...         ...         ...          ...          ...       ...     ...  ...
# 9982       9983    15768163      Griffin          655   Germany  Female   46
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9994       9995    15719294         Wood          800    France  Female   29
# 9997       9998    15584532          Liu          709    France  Female   36
# 9999      10000    15628319       Walker          792    France  Female   28
#
# ...
