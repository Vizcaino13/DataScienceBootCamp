# %% [markdown]
# 1.EDA
# 2. Lambda
# 3.*args and Kwargs
# 4. List comprehension

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing the dataset
path = 'https://raw.githubusercontent.com/gitanuurage/EDA/main/blackFriday_train.csv'
df_train=pd.read_csv(path)
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
##  import the test data
path = 'https://raw.githubusercontent.com/gitanuurage/EDA/main/blackFriday_test.csv'
df_test=pd.read_csv(path)
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
#training file vs test file

# training data trains the model while testing checks (tests) whether this built model works correctly or not


# when you are working on any data science problem ypu normally have a data set with you that you prform tasks on.
# in pratice we divid the data set into two parts
# one part is training data and one is called test data.
# training data is 70-80 of data set
# test data is 20-30%
#machine learng -machine learns on its own.

# %%
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_train.shape
# Out:
# (550068, 12)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df_train.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df_train.loc[1:1,:"City_Category"]
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category
# 1  1000001  P00248942      F  0-17          10             A

# %%
df_train[df_train.Age=="0-17"]
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 85      1000019  P00112542      M  0-17          10             A
# ...         ...        ...    ...   ...         ...           ...
# 549904  1005803  P00375436      M  0-17          10             C
# 550012  1005953  P00370853      M  0-17          10             B
# 550024  1005973  P00370293      M  0-17          10             C
# 550035  1005989  P00370853      F  0-17          10             C
# 550046  1006006  P00375436      F  0-17           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df_train["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df_train["Marital_Status"].unique()
# Out:
# array([0, 1])

# %%
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df_test.shape
# Out:
# (233599, 11)

# %%
df_train.size, df_train.shape, df_train.columns
# Out:
# (6600816,
#  (550068, 12),
#  Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#         'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#         'Product_Category_2', 'Product_Category_3', 'Purchase'],
#        dtype='object'))

# %%
df_test.size, df_test.shape, df_test.columns
# Out:
# (2569589,
#  (233599, 11),
#  Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#         'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#         'Product_Category_2', 'Product_Category_3'],
#        dtype='object'))

# %%
#Merge both train and test data
df=df_train.append(df_test)
df.head()
# Out:
# <ipython-input-30-cb7c3f0c2548>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df_train.append(df_test)
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
# ...

# %%
df.size, df.shape, df.columns
# Out:
# (9404004,
#  (783667, 12),
#  Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#         'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#         'Product_Category_2', 'Product_Category_3', 'Purchase'],
#        dtype='object'))

# %%
df.drop(["User_ID"], axis=1, inplace=True)
df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 233594  P00118942      F  26-35          15             B
# 233595  P00254642      F  26-35          15             B
# 233596  P00031842      F  26-35          15             B
# 233597  P00124742      F  46-50           1             C
# 233598  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.Gender
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 233594    F
# 233595    F
# 233596    F
# 233597    F
# 233598    F
# Name: Gender, Length: 783667, dtype: object

# %%
df["Gender"]
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 233594    F
# 233595    F
# 233596    F
# 233597    F
# 233598    F
# Name: Gender, Length: 783667, dtype: object

# %%
df['Gender'] = pd.get_dummies(df['Gender'], drop_first=1)

# %%
df['Gender'] = df['Gender'].map({'F':0, 'M':1})

# %%
#Categorical variables represent types of data which may be divided into groups.
#a variable that can take on one of a limited number of possible values.

#such as gender, language, geography, True, false

# %%
#preprossing is 60-70 percent of machine learing

# %% [markdown]
# #lamda functions
# generally single liner function

# %%
x= lambda a: a +10
print(x(10))
# Out:
# 20

# %%
x= lambda a, b: a*b+10
print(x(2,8))
# Out:
# 26

# %%
x= lambda a,b,c: a*b*c
print(x(3,5,6))
# Out:
# 90

# %%
Max = lambda a, b : a if(a > b) else b
print(Max(12,-12))
# Out:
# 12

# %%
a =100


b = 200

if (a <150):
  print(a)
  if (a<155):
    print(a)
    if (a < 160):
      print(a)

# %%
result = lambda x,y : f"{x} is smaller than {y}" \
if x < y else (f"{x} is greater than {y}" if x > y \
               else f"{x} is equal to {y}")

print(result(12, 11))
print(result(12, 12))
print(result(12, 13))
# Out:
# 12 is greater than 11
# 12 is equal to 12
# 12 is smaller than 13
