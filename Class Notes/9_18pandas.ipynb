# %%
import pandas as pd

# %%
path="/content/demo_data.xlsx"

df= pd.read_excel(path)

df
# Out:
#     Worker   Wage  Education   Age
# 0      1.0  17.54         12  76.0
# 1      2.0  20.93         10  61.0
# 2      3.0  12.94          8  75.0
# 3      4.0  19.34          6  38.0
# 4      5.0  24.12         12  59.0
# ..     ...    ...        ...   ...
# 75    76.0  25.64         14  74.0
# 76    77.0  38.77         21  41.0
# 77    78.0  21.87         15  75.0
# 78    79.0  27.54         20  46.0
# 79    80.0  23.66         12  49.0
#
# [80 rows x 4 columns]

# %%
df.shape
# Out:
# (80, 4)

# %%
df.dropna()
# Out:
#     Worker   Wage  Education   Age
# 0      1.0  17.54         12  76.0
# 1      2.0  20.93         10  61.0
# 2      3.0  12.94          8  75.0
# 3      4.0  19.34          6  38.0
# 4      5.0  24.12         12  59.0
# ..     ...    ...        ...   ...
# 75    76.0  25.64         14  74.0
# 76    77.0  38.77         21  41.0
# 77    78.0  21.87         15  75.0
# 78    79.0  27.54         20  46.0
# 79    80.0  23.66         12  49.0
#
# [77 rows x 4 columns]

# %%
df_cleaned= df.dropna()

# %%
#df.to_csv('path/to/file.csv', index=False)

# 1) try reading the file as dataframe

# 2) Print mean median std for each column

# 3) Print sum of each column

# 4) max  and min value of each column

# %%
df_cleaned.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-36f04a7384da> in <cell line: 1>()
# ----> 1 df_cleaned.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# 2) Print mean median std for each column
df_cleaned.describe()
# Out:
#           Worker       Wage  Education        Age
# count  77.000000  77.000000  77.000000  77.000000
# mean   41.571429  25.136364  14.000000  49.038961
# std    23.012256   7.396915   4.006574  17.247762
# min     1.000000  10.030000   6.000000  18.000000
# 25%    23.000000  19.150000  12.000000  34.000000
# 50%    42.000000  25.070000  14.000000  51.000000
# 75%    61.000000  30.850000  17.000000  64.000000
# max    80.000000  43.440000  22.000000  77.000000

# %%
# 2) Print mean median std for each column

print("This is the mean:",df_cleaned[["Age","Worker","Wage","Education"]].mean())
print("==========================================")
print("This is the median:",df_cleaned[["Age","Worker","Wage","Education"]].median())
print("==========================================")
print("This is the standard deviation:",df_cleaned[["Age","Worker","Wage","Education"]].std())
# Out:
# This is the mean: Age          49.038961
# Worker       41.571429
# Wage         25.136364
# Education    14.000000
# dtype: float64
# ==========================================
# This is the median: Age          51.00
# Worker       42.00
# Wage         25.07
# Education    14.00
# dtype: float64
# ==========================================
# This is the standard deviation: Age          17.247762
# Worker       23.012256
# Wage          7.396915
# Education     4.006574
# dtype: float64

# %%
# 3) Print sum of each column


print("This is the sum:",df_cleaned[["Age","Worker","Wage","Education"]].sum())
# Out:
# This is the sum: Age          3776.0
# Worker       3201.0
# Wage         1935.5
# Education    1078.0
# dtype: float64

# %%
# 4) max  and min value of each column
print(df_cleaned.max())
print(df_cleaned.min())
# Out:
# Worker       80.00
# Wage         43.44
# Education    22.00
# Age          77.00
# dtype: float64
# Worker        1.00
# Wage         10.03
# Education     6.00
# Age          18.00
# dtype: float64

# %%
# 5) find mean salary of people with age above 50

# 6) find mean salary of people with age below 20

# 7) find which education category has highest wage

# 8) find education and age for highest and lowest wage

# %%
# 5) find mean salary of people with age above 50

df_cleaned.Wage[df["Age"]>50].mean()
# Out:
# 26.29948717948718

# %%
# 6) find mean salary of people with age below 20
df_cleaned.Wage[df["Age"]<20].mean()
# Out:
# 18.759999999999998

# %%
# # 7) find which education category has highest wage

df_cleaned.Education.value_counts()

dictt_mean_wage={}

for i in df_cleaned.Education.value_counts().keys():
  dictt_mean_wage[i]=df_cleaned.Wage[df["Education"]==i].mean()
print(dictt_mean_wage)

#get the key from dict that has the highest value
# Out:
# {12: 22.64363636363636, 16: 29.03875, 8: 17.398571428571426, 15: 27.24857142857143, 18: 31.545714285714286, 10: 19.378333333333334, 17: 28.680000000000003, 14: 27.10833333333333, 20: 32.54, 13: 19.302500000000002, 9: 14.11, 21: 35.39666666666667, 6: 16.134999999999998, 22: 34.95}

# %%
# 8) find education and age for highest and lowest wage


print(df_cleaned[df_cleaned['Wage']==df_cleaned.Wage.min()])
print("===================================================")
print(df_cleaned[df_cleaned['Wage']==df_cleaned.Wage.max()])
