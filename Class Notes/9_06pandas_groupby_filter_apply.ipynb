# %%
#sql you can extract data exactly like filtering it

# !pip install pandas
# !pip install numpy

# %%
import numpy as np
import pandas as pd

# %%
#we are directly taking info from a dataset online

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_chipotle=pd.read_csv(url, sep="\t")
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle[df_chipotle.item_name	=="Chips and Fresh Tomato Salsa"] #this is gathering all the items and orders for chips and salsa
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %%
df_chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#we want to remove the dollar sign from the prices and convert the numer from string to float

for value in df_chipotle.item_price:
  print(value[1:-1]) #we are srating from 1 so its skipping the dollar sign

prices = [float(value[1:-1]) for value in df_chipotle.item_price]

df_chipotle.item_price = prices #assigning the value back to the data

df_chipotle

# %%
#now its been changed
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_chipotle[df_chipotle.item_price >10] #this is items that are greater than 10
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
print(df_chipotle.quantity.max())
print(df_chipotle[df_chipotle.quantity ==15])


# df_chipotle[(df_chipotle.choice_description.isin(['Fajita Vegetables']))]
# df_chipotle[df_chipotle.choice_description.str.contains("Fajita Vegetables")]

df_chipotle.loc[df_chipotle['item_name'] == 'Chicken Salad Bowl', 'item_name'] = 'Chickie salad Bowl'
# df_chipotle.choice_description.describe

df_chipotle
# Out:
# 15
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                           Chickie Bowl
# 4620      1834         1                           Chickie Bowl
# 4621      1834         1                           Chickie Bowl
#
# ...

# %%
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                           Chickie Bowl
# 4620      1834         1                           Chickie Bowl
# 4621      1834         1                           Chickie Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_chipotle[df_chipotle.choice_description.isin(['[Fresh Tomato Salsa]'])]
# Out:
#       order_id  quantity           item_name    choice_description  item_price
# 724        299         1     Chicken Burrito  [Fresh Tomato Salsa]        8.75
# 1014       416         1        Chicken Bowl  [Fresh Tomato Salsa]        8.75
# 1560       634         1  Chicken Soft Tacos  [Fresh Tomato Salsa]        8.75
# 2214       892         1          Steak Bowl  [Fresh Tomato Salsa]        9.25
# 2260       910         1        Chicken Bowl  [Fresh Tomato Salsa]        8.75
# 3310      1327         1        Chickie Bowl  [Fresh Tomato Salsa]        8.75
# 3311      1327         1        Chicken Bowl  [Fresh Tomato Salsa]        8.75
# 3503      1407         1  Steak Crispy Tacos  [Fresh Tomato Salsa]        9.25
# 3634      1454         3     Chicken Burrito  [Fresh Tomato Salsa]       26.25
# 4012      1606         1        Chickie Bowl  [Fresh Tomato Salsa]        8.75
# 4130      1654         1    Steak Soft Tacos  [Fresh Tomato Salsa]        9.25

# %%
df_chipotle.filter(like='item', axis=1)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                           Chickie Bowl       11.25
# 4620                           Chickie Bowl        8.75
# 4621                           Chickie Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
df_chipotle.filter(regex='e$', axis=1)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                           Chickie Bowl       11.25
# 4620                           Chickie Bowl        8.75
# 4621                           Chickie Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df_users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
df_users.occupation.unique() #this gives all the unique ocupations
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
df_users.head() #gives all the top records in the data
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
df_users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
df_users.groupby("occupation").sum()#when using groupby function there should be one groupby associated with it, it gives the sum of all
# Out:
# <ipython-input-88-65b2a164466b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby("occupation").sum()#when using groupby function there should be one groupby associated with iy
#                user_id   age
# occupation
# administrator    34045  3061
# artist           12653   879
# doctor            3736   305
# educator         44356  3991
# engineer         30574  2438
# entertainment     7164   526
# executive        13514  1239
# healthcare        8023   665
# homemaker         3101   228
# lawyer            4309   441
# librarian        24816  2040
# marketing        11383   978
# none              3318   239
# other            56987  3625
# programmer       28745  2186
# retired           7220   883
# salesman          5939   428
# scientist        14419  1102
# ...

# %%
df_users.groupby("occupation").count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
df_users.groupby("occupation").age.count() #this is grouping the data by age and ocupation and counting the ages
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: age, dtype: int64

# %%
df2 = df_users.groupby(['occupation','gender']).count().reset_index()
print(df2)
# Out:
#        occupation gender  user_id  age  zip_code
# 0   administrator      F       36   36        36
# 1   administrator      M       43   43        43
# 2          artist      F       13   13        13
# 3          artist      M       15   15        15
# 4          doctor      M        7    7         7
# 5        educator      F       26   26        26
# 6        educator      M       69   69        69
# 7        engineer      F        2    2         2
# 8        engineer      M       65   65        65
# 9   entertainment      F        2    2         2
# 10  entertainment      M       16   16        16
# 11      executive      F        3    3         3
# 12      executive      M       29   29        29
# 13     healthcare      F       11   11        11
# 14     healthcare      M        5    5         5
# 15      homemaker      F        6    6         6
# 16      homemaker      M        1    1         1
# 17         lawyer      F        2    2         2
# ...

# %%
df2 = df_users.groupby(by=['gender'], dropna=False).sum()
print(df2)


# This code takes a DataFrame (table) called df_users, groups its data by the 'gender' column, and calculates the sum of the numeric values in each group.
# The dropna=False parameter means it doesn't exclude missing (NaN) values when summing.
# Finally, it prints the result, which shows the sum of values for each gender category.
# Out:
#         user_id    age
# gender
# F        131424   9231
# M        313672  22880
# <ipython-input-104-fb13fad56d56>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df_users.groupby(by=['gender'], dropna=False).sum()

# %%
result = df_users.groupby('occupation')['age'].aggregate(['min','max'])
#this is printing the minimum and maximum age of people in certain occupations
print(result)
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
result = df_users.groupby(['occupation', 'gender']).count()

print(result)
# Out:
#                       user_id  age  zip_code
# occupation    gender
# administrator F            36   36        36
#               M            43   43        43
# artist        F            13   13        13
#               M            15   15        15
# doctor        M             7    7         7
# educator      F            26   26        26
#               M            69   69        69
# engineer      F             2    2         2
#               M            65   65        65
# entertainment F             2    2         2
#               M            16   16        16
# executive     F             3    3         3
#               M            29   29        29
# healthcare    F            11   11        11
#               M             5    5         5
# homemaker     F             6    6         6
#               M             1    1         1
# lawyer        F             2    2         2
#               M            10   10        10
# ...

# %%
result = df_users.query("occupation=='homemaker'").groupby(["occupation","gender"]).count()
#this is giving a count of all gender on the occupation of homemaker
print(result)
# Out:
#                    user_id  age  zip_code
# occupation gender
# homemaker  F             6    6         6
#            M             1    1         1

# %%
df_homemaker = df_users[df_users['occupation'] == 'homemaker'].groupby('gender').count()
#this is giving a count of all gender on the occupation of homemaker
df_homemaker
# Out:
#         user_id  age  occupation  zip_code
# gender
# F             6    6           6         6
# M             1    1           1         1

# %%
df_lawyer = df_users[df_users['occupation'] == 'lawyer'].groupby('age').aggregate(["count","min","max"])
df_lawyer
# Out:
#     user_id           gender         occupation                 zip_code  \
#       count  min  max  count min max      count     min     max    count
# age
# 21        1  589  589      1   M   M          1  lawyer  lawyer        1
# 27        1  846  846      1   M   M          1  lawyer  lawyer        1
# 28        1  126  126      1   F   F          1  lawyer  lawyer        1
# 29        1  365  365      1   M   M          1  lawyer  lawyer        1
# 30        1  125  125      1   M   M          1  lawyer  lawyer        1
# 33        1  680  680      1   M   M          1  lawyer  lawyer        1
# 35        1  339  339      1   M   M          1  lawyer  lawyer        1
# 37        1  419  419      1   M   M          1  lawyer  lawyer        1
# 47        1  205  205      1   M   M          1  lawyer  lawyer        1
# 50        1  161  161      1   M   M          1  lawyer  lawyer        1
# 51        1  444  444      1   F   F          1  lawyer  lawyer        1
# ...
