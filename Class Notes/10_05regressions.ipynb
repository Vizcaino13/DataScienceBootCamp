# %% [markdown]
# #polynomial regression
#
# * y=A0+A1x1+A2x2+A2x2... +Anxn
#
# # linear regression
# * y=mx+b
#
# # multilinear regression
# * y=m1x1+m2x2+m2x2... +b
#
#
#
#
#
# when the degree is 0 , y is constant
#
# when the degree is 1 , y is y=mx+b
#
# when the degree is 2 , y is ax^2+bx+c
#
#
# when the degree is greater, y is A0+A1x^1+A2x^2+A2x^2... +Anx^n

# %% [markdown]
# #Support Vector Machine Algorithm
#
# one line is classification and the other is regression. you are seperating two classes of data with the help of one line called a hyperplane. you have support vectors, the distance between the lines are margins, you calculate the distance.
#
# ##Support vectors
#  are the data points that are close to the Hyperplane, they are the data points most difficult to classify, they hold the key for SVM to be optimal decision surface.
#
# ## Margin
# This distance b/w separating hyperplanes and support vector. One reasonable choice as the best hyperplane is the one that represents the largest separation or margin between the two classes
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Descision Tree
#
# On the basis of features you make decisions. you are converting all descions into yes or no to mnake it easier. it is used alot.
#
# # random forrest
#
# A random forest is a machine learning algorithm that uses ensemble learning to solve classification and regression problems. It works by creating multiple decision trees, each of which is trained on a random subset of the data. The algorithm combines the outputs of these trees to generate predictions or classifications.
