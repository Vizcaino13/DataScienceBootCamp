# %%
import pandas as pd

# %%
path="/content/Online_Retail.csv"

df= pd.read_csv(path, encoding='windows-1252')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273453    560833     23322          LARGE WHITE HEART OF WICKER       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 273452    560833     20969  RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273453    560833     23322        LARGE WHITE HEART OF WICKER       1.0
# 273454    560833     23128        FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                 KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                             SCOTTI       NaN
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 273452  7/21/11 12:14       3.75     16891.0  United Kingdom
# 273453  7/21/11 12:14       2.95     16891.0  United Kingdom
# 273454  7/21/11 12:14       4.95     16891.0  United Kingdom
# 273455  7/21/11 12:14       0.85     16891.0  United Kingdom
# 273456            NaN        NaN         NaN             NaN

# %%
# 1) Clean the dataset look and study the dataset for this part

#What i know is wrong with the data

#the dates has seconds
#invoice numbers are written with a c infront
#formatting in stock code is wrong
#quanity is in the negtaives
#missing CustomerIDs and it has a .0 in it
#Stock code has an A in it
#description has na or "?" in it
#remove duplicates

# %%
#Error noticed: some invoice numbers are written with a c in front

df["InvoiceNo"]= df["InvoiceNo"].str.lstrip("C")

df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273453    560833     23322          LARGE WHITE HEART OF WICKER       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#Error noticed: Stock code has letters in it

df["StockCode"]= df["StockCode"].str.strip("ABCDEFGHIJKLMNOPQRSTUVWXYZ")

df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273453    560833     23322          LARGE WHITE HEART OF WICKER       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#Error noticed: the dates was an object and had seconds

from datetime import datetime

# df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%M %d, %Y')
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%m/%d/%y %H:%M')
df['InvoiceDate'] = df['InvoiceDate'].dt.floor('D')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273453    560833     23322          LARGE WHITE HEART OF WICKER       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#quanity is in the negtaives

# df["Quantity"].value_counts()
# #figuring out why they are negative
# QA = [-472, -161, -1206, -272]

# result = df[df["Quantity"].isin(QA)]
# print(result)

# I think it is a typo
df["Quantity"]=df["Quantity"].abs()

df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273453    560833     23322          LARGE WHITE HEART OF WICKER       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#description has na or "?" in it

dA = ["?"]

result = df[df["Description"].isin(dA)]
print(result)
# Out:
#        InvoiceNo StockCode Description  Quantity InvoiceDate  UnitPrice  \
# 7313      537032     21275           ?      30.0  2010-12-03        0.0
# 21518     538090     20956           ?     723.0  2010-12-09        0.0
# 38261     539494     21479           ?     752.0  2010-12-20        0.0
# 43662     540100     22837           ?     106.0  2011-01-04        0.0
# 50806     540558     21258           ?      29.0  2011-01-10        0.0
# 51673     540651     82599           ?     290.0  2011-01-10        0.0
# 68920     541882     48185           ?      57.0  2011-01-24        0.0
# 78235     542861     47591           ?     207.0  2011-02-01        0.0
# 94765     544410     84997           ?     741.0  2011-02-18        0.0
# 97643     544649     21621           ?     400.0  2011-02-22        0.0
# 115806    546138     21815           ?     300.0  2011-03-09        0.0
# 115807    546139     84988           ?    3000.0  2011-03-09        0.0
# ...

# %%
#removing duplicates
df = df.drop_duplicates()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273451    560833     22470                HEART OF WICKER LARGE       1.0
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273451    560833     22470                HEART OF WICKER LARGE       1.0
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#2) Create a Dictionary with the 10 countries that have the most 'Quantity' ordered except UK. Create a bar chart for this

import matplotlib.pyplot as plt

country_quan= df.groupby("Country")["Quantity"].sum().reset_index()
country_quan = country_quan[country_quan["Country"] != "United Kingdom"]
top_10_countries = country_quan.sort_values(by="Quantity", ascending=False).head(10)
country_dict = top_10_countries.set_index("Country")["Quantity"].to_dict()
print(country_dict)



# Extract keys (countries) and values (quantities) from the dictionary
countries = list(country_dict.keys())
quantities = list(country_dict.values())

# Create a bar chart
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(countries, quantities)
plt.title('Top 10 Countries by Quantity (Excluding UK)')
plt.xlabel('Country')
plt.ylabel('Total Quantity')

plt.show()
# Out:
# {'Netherlands': 99940.0, 'EIRE': 67796.0, 'Germany': 61164.0, 'Australia': 55900.0, 'France': 55259.0, 'Sweden': 19886.0, 'Japan': 18892.0, 'Spain': 14237.0, 'Switzerland': 13790.0, 'Belgium': 11405.0}

# %%
# 1) Clean the dataset look and study the dataset for this part

# 2) Create a Dictionary with the 10 countries that have the most 'Quantity' ordered except UK

# 3)  Find Total Sale between two dates entered by user

# 4) Find each Countries Total SALE to find which Countries is highest potential customer

# 5) Which Customer Id has highest purchase in quantity and total and find out the country of it

# 6) Which Customer Id has lowest purchase in quantity and total and find out the country of it

# 7) Find the biggest order In Sale (Cost) which country was the order from and fiind total purchase (Cost) done by that customer ID



# 8) Find how many different customers are available for each country save the count in dictionary also return countries with highest and lowest customer count

# 9) Find which stock code was ordered the most by each country

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271209 entries, 0 to 273456
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    271209 non-null  object
#  1   StockCode    271209 non-null  object
#  2   Description  270211 non-null  object
#  3   Quantity     271208 non-null  float64
#  4   InvoiceDate  271208 non-null  datetime64[ns]
#  5   UnitPrice    271208 non-null  float64
#  6   CustomerID   192928 non-null  float64
#  7   Country      271208 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 18.6+ MB

# %%
#3)  Find Total Sale between two dates entered. line chart

import matplotlib.pyplot as plt
import pandas as pd


start_date = pd.to_datetime("2010-12-01")
end_date = pd.to_datetime("2011-07-21")


filtered_df = df[(df['InvoiceDate'] >= start_date) & (df['InvoiceDate'] <= end_date)]


filtered_df['TotalSale'] = filtered_df['Quantity'] * filtered_df['UnitPrice']
total_sale = filtered_df['TotalSale'].sum()

print("Total Sale between", start_date.date(), "and", end_date.date(), ":", total_sale)

plt.figure(figsize=(10, 6))
plt.plot([start_date, end_date], [0, total_sale], marker='o', linestyle='--')
plt.title('Total Sales Between Two Dates')
plt.xlabel('Dates')
plt.ylabel('Total Sales')
plt.xticks(rotation=70)
plt.show()
# Out:
# <ipython-input-39-06257e4222e9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['TotalSale'] = filtered_df['Quantity'] * filtered_df['UnitPrice']
# Total Sale between 2010-12-01 and 2011-07-21 : 5744362.351

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273451    560833     22470                HEART OF WICKER LARGE       1.0
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (271209, 8)

# %%
#4) Find each Countries Total SALE to find which Countries is highest potential customer.
#do a bar chat for this sale on y axis and countries on x axis

df["Total Sales"] = df["Quantity"] * df["UnitPrice"]
country_sales = df.groupby("Country")["Total Sales"].sum().reset_index()
print(country_sales)

print("===================================================================")
max_sales = country_sales["Total Sales"].max()
max_sales_countries = country_sales[country_sales["Total Sales"] == max_sales]
print("Country(s) with the maximum sales:", max_sales_countries)


x = country_sales["Country"]
y = country_sales["Total Sales"]

# Create the bar chart
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(x, y, color='blue')
plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.title('Total Sales by Country')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability # Ensure labels are displayed properly

# Show the plot
plt.show()
# Out:
# <ipython-input-20-60418ba027dc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Total Sales"] = df["Quantity"] * df["UnitPrice"]
#                  Country  Total Sales
# 0              Australia    86734.520
# 1                Austria     4963.110
# 2                Bahrain      959.880
# 3                Belgium    18736.910
# 4                 Brazil     1143.600
# 5                 Canada     3614.820
# 6        Channel Islands    10227.370
# 7                 Cyprus     8864.610
# 8         Czech Republic      606.770
# 9                Denmark     9436.560
# 10                  EIRE   148548.880
# 11    European Community     1308.750
# 12               Finland    13013.320
# 13                France   100870.790
# ...

# %%
#5) Which Customer Id has highest purchase in quantity and total and find out the country of it

df["Total"] = df["Quantity"] * df["UnitPrice"]
customer_sales = df.groupby(["CustomerID", "Country"])["Total"].agg(['sum', 'count']).reset_index()
print(customer_sales)

max_cust= customer_sales[customer_sales['sum'] == customer_sales['sum'].max()]

print(max_cust)
# Out:
#       CustomerID         Country        sum  count
# 0        12346.0  United Kingdom  154367.20      2
# 1        12347.0         Iceland    2205.95    102
# 2        12348.0         Finland    1487.24     28
# 3        12350.0          Norway     334.40     17
# 4        12352.0          Norway    2522.44     48
# ...          ...             ...        ...    ...
# 3129     18277.0  United Kingdom      12.75      1
# 3130     18280.0  United Kingdom     180.60     10
# 3131     18281.0  United Kingdom      80.82      7
# 3132     18283.0  United Kingdom     951.93    377
# 3133     18287.0  United Kingdom     765.28     29
#
# [3134 rows x 4 columns]
#    CustomerID         Country       sum  count
# 0     12346.0  United Kingdom  154367.2      2
# <ipython-input-21-cb637e5147a0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#6) Which Customer Id has lowest purchase in quantity and total and find out the country of it

df["Total"] = df["Quantity"] * df["UnitPrice"]
customer_sales = df.groupby(["CustomerID", "Country"])["Total"].agg(['sum', 'count']).reset_index()
print(customer_sales)

min_cust= customer_sales[customer_sales['sum'] == customer_sales['sum'].min()]
print(min_cust)
# Out:
# <ipython-input-22-96d3abf780c4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Total"] = df["Quantity"] * df["UnitPrice"]
#       CustomerID         Country        sum  count
# 0        12346.0  United Kingdom  154367.20      2
# 1        12347.0         Iceland    2205.95    102
# 2        12348.0         Finland    1487.24     28
# 3        12350.0          Norway     334.40     17
# 4        12352.0          Norway    2522.44     48
# ...          ...             ...        ...    ...
# 3129     18277.0  United Kingdom      12.75      1
# 3130     18280.0  United Kingdom     180.60     10
# 3131     18281.0  United Kingdom      80.82      7
# 3132     18283.0  United Kingdom     951.93    377
# ...

# %%
#7) Find the biggest order In Sale (Cost) which country was the order from and find total purchase (Cost) done by that customer ID
df["Total"] = df["Quantity"] * df["UnitPrice"]

order_sales = df.groupby(["InvoiceNo", "CustomerID", "Country"])["Total"].agg(['sum', 'count']).reset_index()

max_order= order_sales[order_sales['sum'] == order_sales['sum'].max()]
print(max_order)

customer_id = max_order['CustomerID'].iloc[0]
total_purchase_by_customer = df[df['CustomerID'] == customer_id]['Total'].sum()

print(f"Total purchase (cost) done by Customer ID {customer_id}: {total_purchase_by_customer}")
# Out:
# <ipython-input-23-6e4713a0038f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Total"] = df["Quantity"] * df["UnitPrice"]
#      InvoiceNo  CustomerID         Country      sum  count
# 2331    541431     12346.0  United Kingdom  77183.6      1
# 2333    541433     12346.0  United Kingdom  77183.6      1
# Total purchase (cost) done by Customer ID 12346.0: 154367.2

# %%
#8) Find how many different customers are available for each country save the count in dictionary also return countries with highest and lowest customer count
#bar chart for customer count. customer count on y axis and countries on x axis
customer_count= df.groupby("Country")["CustomerID"].nunique().reset_index()
customer_count_dict = customer_count.set_index("Country")["CustomerID"].to_dict()
print(customer_count_dict)

max_cus= customer_count[customer_count["CustomerID"] == customer_count["CustomerID"].max()]
print("This is the highest customer count",max_cus)

min_cus= customer_count[customer_count["CustomerID"] == customer_count["CustomerID"].min()]
print("This is the lowest customer count",min_cus)



# Extract keys (countries) and values (quantities) from the dictionary
countries1 = list(customer_count_dict.keys())
cus_count = list(customer_count_dict.values())

# Create a bar chart
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed
plt.barh(countries1, cus_count)
plt.title('Customers in each country')
plt.xlabel('Total Customers')
plt.ylabel('Country')
plt.show()
# Out:
# {'Australia': 9, 'Austria': 9, 'Bahrain': 2, 'Belgium': 22, 'Brazil': 1, 'Canada': 3, 'Channel Islands': 7, 'Cyprus': 5, 'Czech Republic': 1, 'Denmark': 5, 'EIRE': 3, 'European Community': 1, 'Finland': 6, 'France': 63, 'Germany': 64, 'Greece': 3, 'Hong Kong': 0, 'Iceland': 1, 'Israel': 2, 'Italy': 10, 'Japan': 6, 'Lebanon': 1, 'Lithuania': 1, 'Malta': 1, 'Netherlands': 8, 'Norway': 5, 'Poland': 4, 'Portugal': 12, 'Saudi Arabia': 1, 'Singapore': 1, 'Spain': 23, 'Sweden': 5, 'Switzerland': 14, 'USA': 1, 'United Arab Emirates': 1, 'United Kingdom': 2830, 'Unspecified': 3}
# This is the highest customer count            Country  CustomerID
# 35  United Kingdom        2830
# This is the lowest customer count       Country  CustomerID
# 16  Hong Kong           0

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 273451    560833     22470                HEART OF WICKER LARGE       1.0
# 273452    560833     20969    RED FLORAL FELTCRAFT SHOULDER BAG       1.0
# 273454    560833     23128          FELTCRAFT BOY JEAN-PAUL KIT       1.0
# 273455    560833     21788                   KIDS RAIN MAC BLUE       1.0
# 273456    560833     22111                               SCOTTI       NaN
#
#        InvoiceDate  UnitPrice  CustomerID         Country  Total Sales  Total
# ...

# %%
#9) Find which stock code was ordered the most by each country

country_stock = df.groupby("Country")["StockCode"].max().reset_index()
print(country_stock)
# Out:
#                  Country StockCode
# 0              Australia     85183
# 1                Austria     85185
# 2                Bahrain     85040
# 3                Belgium     85232
# 4                 Brazil     84971
# 5                 Canada     85232
# 6        Channel Islands     85150
# 7                 Cyprus     85199
# 8         Czech Republic     85206
# 9                Denmark     85159
# 10                  EIRE     90185
# 11    European Community     85132
# 12               Finland     85213
# 13                France     85232
# 14               Germany     90204
# 15                Greece     85215
# 16             Hong Kong     85183
# 17               Iceland     85232
# 18                Israel     84792
# 19                 Italy     85178
# 20                 Japan     85232
# 21               Lebanon     85150
# 22             Lithuania     85206
# 23                 Malta     85230
# 24           Netherlands     85206
# 25                Norway     85232
# ...
